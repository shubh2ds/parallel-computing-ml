# %% [markdown]
# ## Generative Model -Text-Generation-with-Neural-Networks and LSTM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Functions for Processing Text
#
# ### Reading in files as a string text

# %%
def read_file(filepath):

    with open(filepath) as f:
        str_text = f.read()

    return str_text

# %%
path="/content/drive/MyDrive/Text_Generation_keras/moby_book_four_chapters.txt"
read_file(path)
# Out:
# 'Call me Ishmael.  Some years ago--never mind how long\nprecisely--having little or no money in my purse, and nothing\nparticular to interest me on shore, I thought I would sail about a\nlittle and see the watery part of the world.  It is a way I have of\ndriving off the spleen and regulating the circulation.  Whenever I\nfind myself growing grim about the mouth; whenever it is a damp,\ndrizzly November in my soul; whenever I find myself involuntarily\npausing before coffin warehouses, and bringing up the rear of every\nfuneral I meet; and especially whenever my hypos get such an upper\nhand of me, that it requires a strong moral principle to prevent me\nfrom deliberately stepping into the street, and methodically knocking\npeople\'s hats off--then, I account it high time to get to sea as soon\nas I can.  This is my substitute for pistol and ball.  With a\nphilosophical flourish Cato throws himself upon his sword; I quietly\ntake to the ship.  There is nothing surprising in this.  If they but\nknew it, almost all men in their degree, some time or other, cherish\nvery nearly the same feelings towards the ocean with me.\n\nThere now is your insular city of the Manhattoes, belted round by\nwharves as Indian isles by coral reefs--commerce surrounds it with\nher surf.  Right and left, the streets take you waterward.  Its\nextreme downtown is the battery, where that noble mole is washed by\nwaves, and cooled by breezes, which a few hours previous were out of\nsight of land.  Look at the crowds of water-gazers there.\n\nCircumambulate the city of a dreamy Sabbath afternoon.  Go from\nCorlears Hook to Coenties Slip, and from thence, by Whitehall,\nnorthward.  What do you see?--Posted like silent sentinels all around\nthe town, stand thousands upon thousands of mortal men fixed in ocean\nreveries.  Some leaning against the spiles; some seated upon the\npier-heads; some looking over the bulwarks of ships from China; some\nhigh aloft in the rigging, as if striving to get a still better\nseaward peep.  But these are all landsmen; of week days pent up in\nlath and plaster--tied to counters, nailed to benches, clinched to\ndesks.  How then is this?  Are the green fields gone?  What do they\nhere?\n\nBut look! here come more crowds, pacing straight for the water, and\nseemingly bound for a dive.  Strange!  Nothing will content them but\nthe extremest limit of the land; loitering under the shady lee of\nyonder warehouses will not suffice.  No.  They must get just as nigh\nthe water as they possibly can without falling in.  And there they\nstand--miles of them--leagues.  Inlanders all, they come from lanes\nand alleys, streets and avenues--north, east, south, and west.  Yet\nhere they all unite.  Tell me, does the magnetic virtue of the\nneedles of the compasses of all those ships attract them thither?\n\nOnce more.  Say you are in the country; in some high land of lakes.\nTake almost any path you please, and ten to one it carries you down\nin a dale, and leaves you there by a pool in the stream.  There is\nmagic in it.  Let the most absent-minded of men be plunged in his\ndeepest reveries--stand that man on his legs, set his feet a-going,\nand he will infallibly lead you to water, if water there be in all\nthat region.  Should you ever be athirst in the great American\ndesert, try this experiment, if your caravan happen to be supplied\nwith a metaphysical professor.  Yes, as every one knows, meditation\nand water are wedded for ever.\n\nBut here is an artist.  He desires to paint you the dreamiest,\nshadiest, quietest, most enchanting bit of romantic landscape in all\nthe valley of the Saco.  What is the chief element he employs?  There\nstand his trees, each with a hollow trunk, as if a hermit and a\ncrucifix were within; and here sleeps his meadow, and there sleep his\ncattle; and up from yonder cottage goes a sleepy smoke.  Deep into\ndistant woodlands winds a mazy way, reaching to overlapping spurs of\nmountains bathed in their hill-side  ...

# %% [markdown]
# ### Tokenize and Clean Text

# %%
import spacy
nlp = spacy.load('en',disable=['parser', 'tagger','ner'])

nlp.max_length = 1198623

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*+,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
path="/content/drive/MyDrive/Text_Generation_keras/melville-moby_book.txt"
d = read_file(path)
tokens = separate_punc(d)

# %%
tokens=tokens[:100000]

# %%
tokens
# Out:
# ['chapter',
#  '1',
#  'loomings',
#  'call',
#  'me',
#  'ishmael',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to',
#  'interest',
#  'me',
#  'on',
#  'shore',
#  'i',
#  'thought',
#  'i',
#  'would',
#  'sail',
#  'about',
#  'a',
#  'little',
#  'and',
#  'see',
#  'the',
#  'watery',
#  'part',
#  'of',
#  'the',
#  'world',
#  'it',
#  'is',
#  'a',
#  'way',
#  'i',
#  'have',
#  'of',
#  'driving',
#  'off',
#  'the',
#  'spleen',
#  'and',
#  'regulating',
#  'the',
#  'circulation',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'growing',
#  'grim',
#  'about',
#  'the',
#  'mouth',
#  'whenever',
#  'it',
#  'is',
#  'a',
#  'damp',
#  'drizzly',
#  'november',
#  'in',
#  'my',
#  'soul',
#  'whenever',
#  'i',
#  'find',
#  'myself',
#  'involuntarily',
#  'pausing',
#  'before',
#  'coffin',
#  'warehouses',
#  'and',
#  'bringing',
#  'up',
#  'the',
#  'rear',
#  'of',
#  'every',
#  'funeral',
#  'i',
#  'meet',
#  'and',
#  'especially',
#  'whenever',
#  'my',
#  'hypos',
#  'get',
#  'such',
#  'an',
#  'upper',
#  'hand',
#  'of',
#  'me',
#  'that',
#  'it',
#  'requires',
#  'a',
#  'strong',
#  'moral',
#  'principle',
#  'to',
#  'prevent',
#  'me',
#  'from',
#  'deliberately',
#  'stepping',
#  'into',
#  'the',
#  'street',
#  'and',
#  'methodically',
#  'knocking',
#  'people',
#  "'s",
#  'hats',
#  'off',
#  'then',
#  'i',
#  'account',
#  'it',
#  'high',
#  'time',
#  'to',
#  'get',
#  'to',
#  'sea',
#  'as',
#  'soon',
#  'as',
#  'i',
#  'can',
#  'this',
#  'is',
#  'my',
#  'substitute',
#  'for',
#  'pistol',
#  'and',
#  'ball',
#  'with',
#  'a',
#  'philosophical',
#  'flourish',
#  'cato',
#  'throws',
#  'himself',
#  'upon',
#  'his',
#  'sword',
#  'i',
#  'quietly',
#  'take',
#  'to',
#  'the',
#  'ship',
#  'there',
#  'is',
#  'nothing',
#  'surprising',
#  'in',
#  'this',
#  'if',
#  'they',
#  'but',
#  'knew',
#  'it',
#  'almost',
#  'all',
#  'men',
#  'in',
#  'their',
#  'degree',
#  'some',
#  'time',
#  'or',
#  'other',
#  'cherish',
#  'very',
#  'nearly',
#  'the',
#  'same',
#  'feelings',
#  'towards',
#  'the',
#  'ocean',
#  'with',
#  'me',
#  'there',
#  'now',
#  'is',
#  'your',
#  'insular',
#  'city',
#  'of',
#  'the',
#  'manhattoes',
#  'belted',
#  'round',
#  'by',
#  'wharves',
#  'as',
#  'indian',
#  'isles',
#  'by',
#  'coral',
#  'reefs',
#  'commerce',
#  'surrounds',
#  'it',
#  'with',
#  'her',
#  'surf',
#  'right',
#  'and',
#  'left',
#  'the',
#  'streets',
#  'take',
#  'you',
#  'waterward',
#  'its',
#  'extreme',
#  'downtown',
#  'is',
#  'the',
#  'battery',
#  'where',
#  'that',
#  'noble',
#  'mole',
#  'is',
#  'washed',
#  'by',
#  'waves',
#  'and',
#  'cooled',
#  'by',
#  'breezes',
#  'which',
#  'a',
#  'few',
#  'hours',
#  'previous',
#  'were',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'look',
#  'at',
#  'the',
#  'crowds',
#  'of',
#  'water',
#  'gazers',
#  'there',
#  'circumambulate',
#  'the',
#  'city',
#  'of',
#  'a',
#  'dreamy',
#  'sabbath',
#  'afternoon',
#  'go',
#  'from',
#  'corlears',
#  'hook',
#  'to',
#  'coenties',
#  'slip',
#  'and',
#  'from',
#  'thence',
#  'by',
#  'whitehall',
#  'northward',
#  'what',
#  'do',
#  'you',
#  'see?--posted',
#  'like',
#  'silent',
#  'sentinels',
#  'all',
#  'around',
#  'the',
#  'town',
#  'stand',
#  'thousands',
#  'upon',
#  'thousands',
#  'of',
#  'mortal',
#  'men',
#  'fixed',
#  'in',
#  'ocean',
#  'reveries',
#  'some',
#  'leaning',
#  'against',
#  'the',
#  'spiles',
#  'some',
#  'seated',
#  'upon',
#  'the',
#  'pier',
#  'heads',
#  'some',
#  'looking',
#  'over',
#  'the',
#  'bulwarks',
#  'of',
#  'ships',
#  'from',
#  'china',
#  'some',
#  'high',
#  'aloft',
#  'in',
#  'the',
#  'rigging',
#  'as',
#  'if',
#  'striving',
#  'to',
#  'get',
#  'a',
#  'still',
#  'better',
#  'seaward',
#  'peep',
#  'but',
#  'these',
#  'are',
#  'all',
#  'landsmen',
#  'of',
#  'week',
#  'days',
#  'pent',
#  'up',
#  'in',
#  'lath',
#  'and',
#  'plaster',
#  'tied',
#  'to',
#  'counters',
#  'nailed',
#  'to',
#  'benches',
#  'clinched',
#  'to',
#  'desks',
#  'how',
#  'then',
#  'is',
#  'this',
#  'are',
#  'the',
#  'green',
#  'fields',
#  'gone',
#  'what',
#  'do',
#  'they',
#  'here',
#  'but',
#  'look',
#  'here',
#  'come',
#  'more',
#  'crowds',
#  'pacing',
#  'straight',
#  'for',
#  'the',
#  'water',
#  'and',
#  'seemingly',
#  'bound',
#  'for',
#  'a',
#  'dive',
#  'strange',
#  'nothing',
#  'will',
#  'content',
#  'them',
#  'but',
#  'the',
#  'extremest',
#  'limit',
#  'of',
#  'the',
#  'land',
#  'loitering',
#  'under',
#  'the',
#  'shady',
#  'lee',
#  'of',
#  'yonder',
#  'warehouses',
#  'will',
#  'not',
#  'suffice',
#  'no',
#  'they',
#  'must',
#  'get',
#  'just',
#  'as',
#  'nigh',
#  'the',
#  'water',
#  'as',
#  'they',
#  'possibly',
#  'can',
#  'without',
#  'falling',
#  'in',
#  'and',
#  'there',
#  'they',
#  'stand',
#  'miles',
#  'of',
#  'them',
#  'leagues',
#  'inlanders',
#  'all',
#  'they',
#  'come',
#  'from',
#  'lanes',
#  'and',
#  'alleys',
#  'streets',
#  'and',
#  'avenues',
#  'north',
#  'east',
#  'south',
#  'and',
#  'west',
#  'yet',
#  'here',
#  'they',
#  'all',
#  'unite',
#  'tell',
#  'me',
#  'does',
#  'the',
#  'magnetic',
#  'virtue',
#  'of',
#  'the',
#  'needles',
#  'of',
#  'the',
#  'compasses',
#  'of',
#  'all',
#  'those',
#  'ships',
#  'attract',
#  'them',
#  'thither',
#  'once',
#  'more',
#  'say',
#  'you',
#  'are',
#  'in',
#  'the',
#  'country',
#  'in',
#  'some',
#  'high',
#  'land',
#  'of',
#  'lakes',
#  'take',
#  'almost',
#  'any',
#  'path',
#  'you',
#  'please',
#  'and',
#  'ten',
#  'to',
#  'one',
#  'it',
#  'carries',
#  'you',
#  'down',
#  'in',
#  'a',
#  'dale',
#  'and',
#  'leaves',
#  'you',
#  'there',
#  'by',
#  'a',
#  'pool',
#  'in',
#  'the',
#  'stream',
#  'there',
#  'is',
#  'magic',
#  'in',
#  'it',
#  'let',
#  'the',
#  'most',
#  'absent',
#  'minded',
#  'of',
#  'men',
#  'be',
#  'plunged',
#  'in',
#  'his',
#  'deepest',
#  'reveries',
#  'stand',
#  'that',
#  'man',
#  'on',
#  'his',
#  'legs',
#  'set',
#  'his',
#  'feet',
#  'a',
#  'going',
#  'and',
#  'he',
#  'will',
#  'infallibly',
#  'lead',
#  'you',
#  'to',
#  'water',
#  'if',
#  'water',
#  'there',
#  'be',
#  'in',
#  'all',
#  'that',
#  'region',
#  'should',
#  'you',
#  'ever',
#  'be',
#  'athirst',
#  'in',
#  'the',
#  'great',
#  'american',
#  'desert',
#  'try',
#  'this',
#  'experiment',
#  'if',
#  'your',
#  'caravan',
#  'happen',
#  'to',
#  'be',
#  'supplied',
#  'with',
#  'a',
#  'metaphysical',
#  'professor',
#  'yes',
#  'as',
#  'every',
#  'one',
#  'knows',
#  'meditation',
#  'and',
#  'water',
#  'are',
#  'wedded',
#  'for',
#  'ever',
#  'but',
#  'here',
#  'is',
#  'an',
#  'artist',
#  'he',
#  'desires',
#  'to',
#  'paint',
#  'you',
#  'the',
#  'dreamiest',
#  'shadiest',
#  'quietest',
#  'most',
#  'enchanting',
#  'bit',
#  'of',
#  'romantic',
#  'landscape',
#  'in',
#  'all',
#  'the',
#  'valley',
#  'of',
#  'the',
#  'saco',
#  'what',
#  'is',
#  'the',
#  'chief',
#  'element',
#  'he',
#  'employs',
#  'there',
#  'stand',
#  'his',
#  'trees',
#  'each',
#  'with',
#  'a',
#  'hollow',
#  'trunk',
#  'as',
#  'if',
#  'a',
#  'hermit',
#  'and',
#  'a',
#  'crucifix',
#  'were',
#  'within',
#  'and',
#  'here',
#  'sleeps',
#  'his',
#  'meadow',
#  'and',
#  'there',
#  'sleep',
#  'his',
#  'cattle',
#  'and',
#  'up',
#  'from',
#  'yonder',
#  'cottage',
#  'goes',
#  'a',
#  'sleepy',
#  'smoke',
#  'deep',
#  'into',
#  'distant',
#  'woodlands',
#  'winds',
#  'a',
#  'mazy',
#  'way',
#  'reaching',
#  'to',
#  'overlapping',
#  'spurs',
#  'of',
#  'mountains',
#  'bathed',
#  'in',
#  'their',
#  'hill',
#  'side',
#  'blue',
#  'but',
#  'though',
#  'the',
#  'picture',
#  'lies',
#  'thus',
#  'tranced',
#  'and',
#  'though',
#  'this',
#  'pine',
#  'tree',
#  'shakes',
#  'down',
#  'its',
#  'sighs',
#  'like',
#  'leaves',
#  'upon',
#  'this',
#  'shepherd',
#  "'s",
#  'head',
#  'yet',
#  'all',
#  'were',
#  'vain',
#  'unless',
#  'the',
#  'shepherd',
#  "'s",
#  'eye',
#  'were',
#  'fixed',
#  'upon',
#  'the',
#  'magic',
#  'stream',
#  'before',
#  'him',
#  'go',
#  'visit',
#  'the',
#  'prairies',
#  'in',
#  'june',
#  'when',
#  'for',
#  'scores',
#  'on',
#  'scores',
#  'of',
#  'miles',
#  'you',
#  'wade',
#  'knee',
#  'deep',
#  'among',
#  'tiger',
#  'lilies',
#  'what',
#  'is',
#  'the',
#  'one',
#  'charm',
#  'wanting?--water',
#  'there',
#  'is',
#  'not',
#  'a',
#  'drop',
#  'of',
#  'water',
#  'there',
#  'were',
#  'niagara',
#  'but',
#  'a',
#  'cataract',
#  'of',
#  'sand',
#  'would',
#  'you',
#  'travel',
#  'your',
#  'thousand',
#  'miles',
#  'to',
#  'see',
#  'it',
#  'why',
#  'did',
#  'the',
#  'poor',
#  'poet',
#  'of',
#  'tennessee',
#  'upon',
#  'suddenly',
#  'receiving',
#  'two',
#  'handfuls',
#  'of',
#  'silver',
#  'deliberate',
#  'whether',
#  'to',
#  'buy',
#  'him',
#  'a',
#  'coat',
#  'which',
#  'he',
#  'sadly',
#  'needed',
#  'or',
#  'invest',
#  'his',
#  'money',
#  'in',
#  'a',
#  'pedestrian',
#  'trip',
#  'to',
#  'rockaway',
#  'beach',
#  'why',
#  'is',
#  'almost',
#  'every',
#  'robust',
#  'healthy',
#  'boy',
#  'with',
#  'a',
#  'robust',
#  'healthy',
#  'soul',
#  'in',
#  'him',
#  'at',
#  'some',
#  'time',
#  'or',
#  'other',
#  'crazy',
#  'to',
#  'go',
#  'to',
#  'sea',
#  'why',
#  'upon',
#  'your',
#  'first',
#  'voyage',
#  'as',
#  'a',
#  'passenger',
#  'did',
#  'you',
#  'yourself',
#  'feel',
#  'such',
#  'a',
#  'mystical',
#  'vibration',
#  'when',
#  'first',
#  'told',
#  'that',
#  'you',
#  'and',
#  'your',
#  'ship',
#  'were',
#  'now',
#  'out',
#  'of',
#  'sight',
#  'of',
#  'land',
#  'why',
#  'did',
#  'the',
#  'old',
#  'persians',
#  'hold',
#  'the',
#  'sea',
#  'holy',
#  'why',
#  'did',
#  'the',
#  'greeks',
#  'give',
#  'it',
#  'a',
#  'separate',
#  'deity',
#  'and',
#  'own',
#  'brother',
#  'of',
#  'jove',
#  'surely',
#  'all',
#  'this',
#  'is',
#  'not',
#  'without',
#  'meaning',
#  'and',
#  'still',
#  'deeper',
#  'the',
#  'meaning',
#  'of',
#  'that',
#  'story',
#  'of',
#  'narcissus',
#  'who',
#  'because',
#  'he',
#  'could',
#  'not',
#  'grasp',
#  'the',
#  'tormenting',
#  'mild',
#  'image',
#  'he',
#  'saw',
#  'in',
#  'the',
#  'fountain',
#  'plunged',
#  'into',
#  'it',
#  'and',
#  'was',
#  'drowned',
#  'but',
#  'that',
#  'same',
#  'image',
#  'we',
#  'ourselves',
#  'see',
#  'in',
#  'all',
#  'rivers',
#  'and',
#  'oceans',
#  'it',
#  'is',
#  'the',
#  'image',
#  'of',
#  'the',
#  'ungraspable',
#  'phantom',
#  'of',
#  'life',
#  'and',
#  'this',
#  'is',
#  'the',
#  'key',
#  'to',
#  'it',
#  'all',
#  'now',
#  'when',
#  'i',
#  'say',
#  'that',
#  'i',
#  'am',
#  'in',
#  'the',
#  'habit',
#  'of',
#  'going',
#  'to',
#  'sea',
#  'whenever',
#  'i',
#  'begin',
#  'to',
#  'grow',
#  'hazy',
#  'about',
#  ...]

# %%
len(tokens)
# Out:
# 100000

# %%
4431/25
# Out:
# 177.24

# %% [markdown]
# ## Create Sequences of Tokens

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):

    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]

    # Add to list of sequences
    text_sequences.append(seq)

# %%
' '.join(text_sequences[0])
# Out:
# 'chapter 1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to'

# %%
' '.join(text_sequences[1])
# Out:
# '1 loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest'

# %%
' '.join(text_sequences[2])
# Out:
# 'loomings call me ishmael some years ago never mind how long precisely having little or no money in my purse and nothing particular to interest me'

# %%
len(text_sequences)
# Out:
# 99974

# %% [markdown]
# # Keras

# %% [markdown]
# ### Keras Tokenization

# %%
from keras.preprocessing.text import Tokenizer

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [164,
#  5611,
#  11718,
#  390,
#  32,
#  640,
#  46,
#  259,
#  778,
#  111,
#  243,
#  123,
#  93,
#  1138,
#  327,
#  86,
#  38,
#  44,
#  1137,
#  6,
#  39,
#  2182,
#  3,
#  181,
#  421,
#  5]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'to',
#  6: 'in',
#  7: 'that',
#  8: 'his',
#  9: 'i',
#  10: 'it',
#  11: 'he',
#  12: 'was',
#  13: 'but',
#  14: 'with',
#  15: 'as',
#  16: 'all',
#  17: 'for',
#  18: "'s",
#  19: 'is',
#  20: 'at',
#  21: 'this',
#  22: 'not',
#  23: 'him',
#  24: 'be',
#  25: 'from',
#  26: 'by',
#  27: 'on',
#  28: 'so',
#  29: 'there',
#  30: 'whale',
#  31: 'had',
#  32: 'me',
#  33: 'you',
#  34: 'one',
#  35: 'have',
#  36: 'were',
#  37: "'",
#  38: 'or',
#  39: 'my',
#  40: 'what',
#  41: 'they',
#  42: 'now',
#  43: 'then',
#  44: 'no',
#  45: 'like',
#  46: 'some',
#  47: 'upon',
#  48: 'which',
#  49: 'when',
#  50: 'ye',
#  51: 'their',
#  52: 'out',
#  53: 'more',
#  54: 'an',
#  55: 'ship',
#  56: 'man',
#  57: 'up',
#  58: 'are',
#  59: 'would',
#  60: 'we',
#  61: 'into',
#  62: 'captain',
#  63: 'them',
#  64: 'if',
#  65: 'who',
#  66: 'old',
#  67: 'do',
#  68: 'such',
#  69: 'though',
#  70: 'been',
#  71: 'sea',
#  72: 'other',
#  73: 'ahab',
#  74: 'over',
#  75: 'down',
#  76: 'about',
#  77: 'said',
#  78: 'queequeg',
#  79: 'yet',
#  80: 'these',
#  81: 'any',
#  82: 'time',
#  83: 'only',
#  84: 'those',
#  85: 'will',
#  86: 'little',
#  87: 'very',
#  88: 'her',
#  89: 'white',
#  90: 'than',
#  91: 'did',
#  92: 'seemed',
#  93: 'long',
#  94: 'still',
#  95: "n't",
#  96: 'before',
#  97: 'here',
#  98: 'most',
#  99: 'great',
#  100: 'has',
#  101: 'our',
#  102: 'after',
#  103: 'its',
#  104: 'could',
#  105: 'way',
#  106: 'himself',
#  107: 'men',
#  108: 'say',
#  109: 'us',
#  110: 'your',
#  111: 'never',
#  112: 'well',
#  113: 'see',
#  114: 'last',
#  115: 'must',
#  116: 'much',
#  117: 'head',
#  118: 'two',
#  119: 'good',
#  120: 'three',
#  121: 'first',
#  122: 'can',
#  123: 'how',
#  124: 'thought',
#  125: 'own',
#  126: 'every',
#  127: 'being',
#  128: 'again',
#  129: 'off',
#  130: 'may',
#  131: 'ever',
#  132: 'whales',
#  133: 'round',
#  134: 'sort',
#  135: 'even',
#  136: 'hand',
#  137: 'same',
#  138: 'while',
#  139: 'where',
#  140: 'boat',
#  141: 'world',
#  142: 'through',
#  143: 'go',
#  144: 'made',
#  145: 'might',
#  146: 'many',
#  147: 'thou',
#  148: 'come',
#  149: 'among',
#  150: 'almost',
#  151: 'night',
#  152: 'look',
#  153: 'without',
#  154: 'back',
#  155: 'deck',
#  156: 'god',
#  157: 'whaling',
#  158: 'nor',
#  159: 'too',
#  160: 'should',
#  161: 'thing',
#  162: 'day',
#  163: 'bildad',
#  164: 'chapter',
#  165: 'things',
#  166: 'sperm',
#  167: 'tell',
#  168: 'know',
#  169: 'peleg',
#  170: 'starbuck',
#  171: 'against',
#  172: 'away',
#  173: 'seen',
#  174: 'stubb',
#  175: 'something',
#  176: 'water',
#  177: 'side',
#  178: 'life',
#  179: 'think',
#  180: 'far',
#  181: 'nothing',
#  182: 'voyage',
#  183: 'take',
#  184: 'times',
#  185: 'pequod',
#  186: 'part',
#  187: 'right',
#  188: 'why',
#  189: 'came',
#  190: 'bed',
#  191: 'crew',
#  192: 'eyes',
#  193: 'each',
#  194: 'sailor',
#  195: 'nantucket',
#  196: 'fish',
#  197: 'jonah',
#  198: 'small',
#  199: 'let',
#  200: 'mast',
#  201: 'flask',
#  202: 'just',
#  203: 'once',
#  204: 'place',
#  205: 'found',
#  206: 'she',
#  207: 'aye',
#  208: 'new',
#  209: 'soon',
#  210: 'towards',
#  211: 'between',
#  212: 'harpooneer',
#  213: 'perhaps',
#  214: 'cabin',
#  215: 'does',
#  216: 'make',
#  217: '\n\n\n\n',
#  218: 'whole',
#  219: 'days',
#  220: 'heard',
#  221: 'till',
#  222: 'half',
#  223: 'sail',
#  224: 'wild',
#  225: 'seas',
#  226: 'mate',
#  227: 'soul',
#  228: 'going',
#  229: 'however',
#  230: 'face',
#  231: 'hands',
#  232: 'room',
#  233: 'cried',
#  234: 'ships',
#  235: 'thus',
#  236: 'air',
#  237: 'black',
#  238: 'name',
#  239: 'called',
#  240: 'both',
#  241: 'along',
#  242: 'full',
#  243: 'mind',
#  244: 'high',
#  245: 'strange',
#  246: 'under',
#  247: 'am',
#  248: 'another',
#  249: 'looked',
#  250: 'moment',
#  251: 'myself',
#  252: 'board',
#  253: 'young',
#  254: 'matter',
#  255: 'stood',
#  256: 'went',
#  257: 'indeed',
#  258: 'morning',
#  259: 'years',
#  260: 'stand',
#  261: 'give',
#  262: 'true',
#  263: 'lay',
#  264: 'known',
#  265: 'land',
#  266: 'eye',
#  267: 'because',
#  268: "'ll",
#  269: 'also',
#  270: 'moby',
#  271: 'dick',
#  272: 'feet',
#  273: 'boats',
#  274: 'whether',
#  275: 'light',
#  276: 'large',
#  277: 'oh',
#  278: 'thee',
#  279: 'saw',
#  280: 'enough',
#  281: 'open',
#  282: 'hard',
#  283: 'death',
#  284: 'four',
#  285: 'certain',
#  286: 'word',
#  287: 'heart',
#  288: 'steelkilt',
#  289: 'book',
#  290: 'always',
#  291: 'get',
#  292: 'few',
#  293: 'looking',
#  294: 'set',
#  295: 'rather',
#  296: 'put',
#  297: 'whalemen',
#  298: 'shall',
#  299: 'left',
#  300: 'whose',
#  301: 'sir',
#  302: 'within',
#  303: 'business',
#  304: 'next',
#  305: 'often',
#  306: 'present',
#  307: 'thy',
#  308: 'ocean',
#  309: 'sight',
#  310: 'better',
#  311: 'hold',
#  312: 'turn',
#  313: 'leg',
#  314: 'yes',
#  315: 'poor',
#  316: 'sailors',
#  317: 'dead',
#  318: 'door',
#  319: 'turned',
#  320: 'grand',
#  321: 'arm',
#  322: 'hear',
#  323: 'savage',
#  324: 'home',
#  325: 'fishery',
#  326: 'gentlemen',
#  327: 'having',
#  328: 'heads',
#  329: 'sleep',
#  330: 'since',
#  331: 'craft',
#  332: 'ere',
#  333: 'itself',
#  334: 'landlord',
#  335: 'standing',
#  336: 'harpooneers',
#  337: 'waters',
#  338: 'peculiar',
#  339: 'knew',
#  340: 'order',
#  341: 'above',
#  342: 'sat',
#  343: 'seem',
#  344: 'seems',
#  345: 'got',
#  346: 'therefore',
#  347: 'king',
#  348: 'especially',
#  349: 'people',
#  350: 'deep',
#  351: 'told',
#  352: 'harpoon',
#  353: 'took',
#  354: 'best',
#  355: 'felt',
#  356: 'sun',
#  357: 'least',
#  358: 'living',
#  359: 'cape',
#  360: 'fine',
#  361: 'sure',
#  362: 'line',
#  363: 'done',
#  364: 'pipe',
#  365: 'mates',
#  366: 'find',
#  367: 'indian',
#  368: 'somehow',
#  369: 'island',
#  370: 'dark',
#  371: 'cold',
#  372: 'house',
#  373: 'watch',
#  374: 'case',
#  375: 'oil',
#  376: 'mr.',
#  377: 'below',
#  378: 'green',
#  379: 'chief',
#  380: 'feel',
#  381: 'besides',
#  382: 'point',
#  383: 'rest',
#  384: 'together',
#  385: 'shipmates',
#  386: 'coming',
#  387: 'turning',
#  388: 'ground',
#  389: 'whiteness',
#  390: 'call',
#  391: 'goes',
#  392: 'boy',
#  393: 'general',
#  394: 'short',
#  395: 'reason',
#  396: 'sailed',
#  397: 'broad',
#  398: 'common',
#  399: 'whom',
#  400: 'iron',
#  401: 'mark',
#  402: 'seamen',
#  403: 'fire',
#  404: 'began',
#  405: 'town',
#  406: 'story',
#  407: 'boys',
#  408: 'anything',
#  409: 'easy',
#  410: 'horn',
#  411: 'kept',
#  412: 'says',
#  413: 'body',
#  414: 'table',
#  415: 'used',
#  416: 'end',
#  417: 'weather',
#  418: 'top',
#  419: 'sometimes',
#  420: 'pull',
#  421: 'particular',
#  422: 'gone',
#  423: 'mean',
#  424: 'themselves',
#  425: 'quite',
#  426: 'quarter',
#  427: 'second',
#  428: 'run',
#  429: 'famous',
#  430: 'teeth',
#  431: 'keep',
#  432: 'ivory',
#  433: 'bottom',
#  434: 'ready',
#  435: 'fellow',
#  436: 'lord',
#  437: 'length',
#  438: 'curious',
#  439: 'several',
#  440: 'creature',
#  441: 'aspect',
#  442: 'noble',
#  443: 'waves',
#  444: 'taking',
#  445: 'bear',
#  446: 'less',
#  447: 'rolled',
#  448: 'further',
#  449: 'wide',
#  450: 'i.',
#  451: 'nevertheless',
#  452: 'passage',
#  453: 'beneath',
#  454: 'stranger',
#  455: 'seeing',
#  456: 'running',
#  457: 'earth',
#  458: 'given',
#  459: 'tashtego',
#  460: 'lakeman',
#  461: 'fixed',
#  462: 'american',
#  463: 'either',
#  464: 'heaven',
#  465: 'various',
#  466: 'purpose',
#  467: 'forth',
#  468: 'suppose',
#  469: 'queer',
#  470: 'wind',
#  471: 'fact',
#  472: 'help',
#  473: 'comes',
#  474: 'ashore',
#  475: 'near',
#  476: 'chance',
#  477: 'concerning',
#  478: 'lost',
#  479: 'touching',
#  480: 'taken',
#  481: 'radney',
#  482: 'account',
#  483: 'straight',
#  484: 'snow',
#  485: 'chase',
#  486: 'sign',
#  487: 'struck',
#  488: 'hundred',
#  489: 'mine',
#  490: 'spring',
#  491: 'kill',
#  492: 'devil',
#  493: 'saying',
#  494: 'heavy',
#  495: 'truth',
#  496: 'whaleman',
#  497: 'hat',
#  498: 'fear',
#  499: 'sudden',
#  500: 'mere',
#  501: 'means',
#  502: 'vessel',
#  503: 'mouth',
#  504: 'ten',
#  505: 'thousand',
#  506: 'making',
#  507: 'idea',
#  508: 'port',
#  509: 'mighty',
#  510: 'broken',
#  511: 'five',
#  512: 'manner',
#  513: "'em",
#  514: 'person',
#  515: 'live',
#  516: 'instant',
#  517: 'object',
#  518: 'english',
#  519: 'greenland',
#  520: 'strong',
#  521: 'silent',
#  522: 'nigh',
#  523: 'speak',
#  524: 'forecastle',
#  525: 'ai',
#  526: 'considering',
#  527: 'monster',
#  528: 'wonder',
#  529: 'stop',
#  530: 'behind',
#  531: 'foot',
#  532: 'cut',
#  533: 'want',
#  534: 'company',
#  535: 'coast',
#  536: 'unknown',
#  537: 'ca',
#  538: 'wo',
#  539: 'close',
#  540: 'tomahawk',
#  541: 'sound',
#  542: 'work',
#  543: 'nature',
#  544: 'squall',
#  545: 'don',
#  546: 'hours',
#  547: 'mortal',
#  548: 'bulwarks',
#  549: 'bound',
#  550: 'suddenly',
#  551: 'coat',
#  552: 'holy',
#  553: 'else',
#  554: 'perils',
#  555: 'quick',
#  556: 'pacific',
#  557: 'leviathan',
#  558: 'meanwhile',
#  559: 'low',
#  560: 'voice',
#  561: 'sitting',
#  562: 'alone',
#  563: 'visible',
#  564: 'jaw',
#  565: 'knife',
#  566: 'chest',
#  567: 'certainly',
#  568: 'possible',
#  569: 'gave',
#  570: 'pretty',
#  571: 'plainly',
#  572: 'e',
#  573: 'touch',
#  574: 'question',
#  575: 'storm',
#  576: 'bows',
#  577: 'father',
#  578: 'main',
#  579: 'command',
#  580: 'aft',
#  581: 'brow',
#  582: 'stern',
#  583: 'instances',
#  584: 'nearly',
#  585: 'legs',
#  586: 'blue',
#  587: 'answer',
#  588: 'nay',
#  589: 'words',
#  590: 'sharp',
#  591: 'altogether',
#  592: 'clear',
#  593: 'mad',
#  594: 'jacket',
#  595: 'slowly',
#  596: 'form',
#  597: 'makes',
#  598: 'state',
#  599: 'friend',
#  600: 'born',
#  601: 'bodily',
#  602: 'blood',
#  603: 'hunters',
#  604: 'officers',
#  605: 'shore',
#  606: 'around',
#  607: 'seated',
#  608: 'miles',
#  609: 'vain',
#  610: 'thinks',
#  611: 'captains',
#  612: 'view',
#  613: 'passed',
#  614: 'finally',
#  615: 'parts',
#  616: 'bedford',
#  617: 'red',
#  618: 'human',
#  619: 'vast',
#  620: 'fifty',
#  621: 'supper',
#  622: 'placed',
#  623: 'feeling',
#  624: 'doubt',
#  625: 'thinking',
#  626: 'arms',
#  627: 'entire',
#  628: 'hope',
#  629: 'pilot',
#  630: 'bow',
#  631: 'turns',
#  632: 'strike',
#  633: 'speaking',
#  634: 'wholly',
#  635: 'hussey',
#  636: 'forward',
#  637: 'natural',
#  638: 'daggoo',
#  639: 'fin',
#  640: 'ishmael',
#  641: 'interest',
#  642: 'watery',
#  643: 'quietly',
#  644: 'degree',
#  645: 'try',
#  646: 'knows',
#  647: 'distant',
#  648: 'unless',
#  649: 'yourself',
#  650: 'single',
#  651: 'others',
#  652: 'following',
#  653: 'hour',
#  654: 'pulpit',
#  655: 'tossed',
#  656: 'plain',
#  657: 'wall',
#  658: 'lance',
#  659: 'generally',
#  660: 'sleeping',
#  661: 'hammock',
#  662: 'leaving',
#  663: 'interval',
#  664: 'christian',
#  665: 'terrible',
#  666: 'completely',
#  667: 'dinner',
#  668: 'drawing',
#  669: 'pagan',
#  670: 'during',
#  671: 'whatever',
#  672: 'wise',
#  673: 'carried',
#  674: 'terrors',
#  675: 'hence',
#  676: 'woe',
#  677: 'o',
#  678: 'sails',
#  679: 'hunt',
#  680: 'cruising',
#  681: 'porpoise',
#  682: 'previous',
#  683: 'aloft',
#  684: 'winds',
#  685: 'kind',
#  686: 'ah',
#  687: 'merchant',
#  688: 'formed',
#  689: 'drawn',
#  690: 'circumstances',
#  691: 'late',
#  692: 'brought',
#  693: 'inn',
#  694: 'ice',
#  695: 'followed',
#  696: 'ha',
#  697: 'warm',
#  698: 'stands',
#  699: 'number',
#  700: 'hole',
#  701: "'ve",
#  702: 'thoughts',
#  703: 'break',
#  704: 'otherwise',
#  705: 'floor',
#  706: 'anchor',
#  707: 'eyeing',
#  708: 'thrown',
#  709: 'similar',
#  710: 'smoking',
#  711: 'show',
#  712: 'gale',
#  713: 'art',
#  714: 'lofty',
#  715: 'gold',
#  716: 'sleet',
#  717: 'hearts',
#  718: 'rope',
#  719: 'fell',
#  720: 'complete',
#  721: 'power',
#  722: 'intervals',
#  723: 'free',
#  724: 'lower',
#  725: 'elijah',
#  726: 'dignity',
#  727: 'folio',
#  728: 'ii',
#  729: 'streets',
#  730: 'leaning',
#  731: 'bit',
#  732: 'honour',
#  733: 'really',
#  734: 'already',
#  735: 'became',
#  736: 'tall',
#  737: 'corner',
#  738: 'talk',
#  739: 'holding',
#  740: 'fiery',
#  741: 'final',
#  742: 'tail',
#  743: 'telling',
#  744: 'evening',
#  745: 'become',
#  746: 'darted',
#  747: 'kings',
#  748: 'none',
#  749: 'getting',
#  750: 'duty',
#  751: 'yellow',
#  752: 'war',
#  753: 'hardly',
#  754: 'year',
#  755: 'gay',
#  756: 'ways',
#  757: 'self',
#  758: 'burst',
#  759: 'sweet',
#  760: 'regarded',
#  761: 'headed',
#  762: 'cross',
#  763: 'remained',
#  764: 'nose',
#  765: 'hinted',
#  766: 'owners',
#  767: 'post',
#  768: 'start',
#  769: 'nantucketer',
#  770: 'mrs.',
#  771: 'yojo',
#  772: 'hammer',
#  773: 'seven',
#  774: 'sailing',
#  775: 'scuttle',
#  776: 'row',
#  777: 'pumps',
#  778: 'ago',
#  779: 'sword',
#  780: 'possibly',
#  781: 'south',
#  782: 'country',
#  783: 'hollow',
#  784: 'smoke',
#  785: 'beach',
#  786: 'glory',
#  787: 'officer',
#  788: 'decks',
#  789: 'instance',
#  790: 'fore',
#  791: 'unaccountable',
#  792: 'nameless',
#  793: 'darkness',
#  794: 'boots',
#  795: 'ears',
#  796: 'lie',
#  797: 'hung',
#  798: 'lines',
#  799: 'hair',
#  800: 'cannibal',
#  801: 'hump',
#  802: 'wrinkled',
#  803: 'fancy',
#  804: 'cases',
#  805: 'caught',
#  806: 'shipmate',
#  807: 'flew',
#  808: 'stove',
#  809: 'ones',
#  810: 'mat',
#  811: 'fresh',
#  812: 'aboard',
#  813: 'real',
#  814: 'takes',
#  815: 'lamp',
#  816: 'circumstance',
#  817: 'third',
#  818: 'awful',
#  819: 'alive',
#  820: 'hunted',
#  821: 'breakfast',
#  822: 'proper',
#  823: 'ho',
#  824: 'atlantic',
#  825: 'regular',
#  826: 'step',
#  827: 'son',
#  828: 'ancient',
#  829: 'friends',
#  830: 'pass',
#  831: 'delight',
#  832: 'spirit',
#  833: 'except',
#  834: 'native',
#  835: 'cod',
#  836: 'spread',
#  837: 'hailed',
#  838: "d'ye",
#  839: 'vessels',
#  840: 'sorts',
#  841: 'steward',
#  842: 'encounter',
#  843: 'octavo',
#  844: 'voyages',
#  845: 'coffin',
#  846: 'rear',
#  847: 'rigging',
#  848: 'content',
#  849: 'yonder',
#  850: 'mild',
#  851: 'ourselves',
#  852: 'grow',
#  853: 'marvellous',
#  854: 'battle',
#  855: 'love',
#  856: 'bag',
#  857: 'started',
#  858: 'original',
#  859: 'beyond',
#  860: 'negro',
#  861: 'dim',
#  862: 'jet',
#  863: 'window',
#  864: 'shadows',
#  865: 'planks',
#  866: 'jaws',
#  867: 'sought',
#  868: 'forehead',
#  869: 'mariners',
#  870: 'wake',
#  871: 'pursuit',
#  872: 'private',
#  873: 'fair',
#  874: 'spare',
#  875: 'guess',
#  876: 'understand',
#  877: 'cause',
#  878: 'likewise',
#  879: 'honest',
#  880: 'hot',
#  881: 'shipped',
#  882: 'hidden',
#  883: 'follow',
#  884: 'ran',
#  885: 'figure',
#  886: 'troubled',
#  887: 'inch',
#  888: 'events',
#  889: 'leave',
#  890: 'solitary',
#  891: 'bones',
#  892: 'whence',
#  893: 'instead',
#  894: 'fishermen',
#  895: 'fail',
#  896: 'sky',
#  897: 'history',
#  898: 'former',
#  899: 'beat',
#  900: 'across',
#  901: 'lesson',
#  902: 'wharf',
#  903: 'whaler',
#  904: 'madness',
#  905: 'strangely',
#  906: 'brain',
#  907: 'according',
#  908: 'rising',
#  909: 'secret',
#  910: 'invested',
#  911: 'latitudes',
#  912: 'pip',
#  913: 'dough',
#  914: 'iii',
#  915: 'terror',
#  916: 'whenever',
#  917: 'street',
#  918: 'lee',
#  919: 'lead',
#  920: 'separate',
#  921: 'oceans',
#  922: 'phantom',
#  923: 'key',
#  924: 'lungs',
#  925: 'needs',
#  926: 'considerable',
#  927: 'creatures',
#  928: 'huge',
#  929: 'royal',
#  930: 'putting',
#  931: 'orders',
#  932: 'doubtless',
#  933: 'presented',
#  934: 'social',
#  935: 'swung',
#  936: 'throw',
#  937: 'bright',
#  938: 'thick',
#  939: 'harpoons',
#  940: 'wooden',
#  941: 'spot',
#  942: 'worse',
#  943: 'howling',
#  944: 'repeated',
#  945: 'throwing',
#  946: 'winter',
#  947: 'masts',
#  948: 'received',
#  949: 'avast',
#  950: 'fain',
#  951: 'nt',
#  952: 'chap',
#  953: 'resolved',
#  954: 'held',
#  955: 'six',
#  956: 'seldom',
#  957: 'cry',
#  958: 'deal',
#  959: 'sake',
#  960: 'answered',
#  961: 'shouted',
#  962: 'thereby',
#  963: 'kick',
#  964: 'lighted',
#  965: 'somewhere',
#  966: 'clam',
#  967: 'seaman',
#  968: 'employed',
#  969: 'colour',
#  970: 'course',
#  971: 'marked',
#  972: 'empty',
#  973: 'meantime',
#  974: 'places',
#  975: 'rolling',
#  976: 'entirely',
#  977: 'shock',
#  978: 'naught',
#  979: 'aside',
#  980: 'commanded',
#  981: 'piece',
#  982: 'hue',
#  983: 'looks',
#  984: 'silence',
#  985: 'seek',
#  986: 'spite',
#  987: 'spiritual',
#  988: 'helm',
#  989: 'rose',
#  990: 'modern',
#  991: 'cries',
#  992: 'glance',
#  993: 'race',
#  994: 'fall',
#  995: 'dropped',
#  996: 'laid',
#  997: 'twenty',
#  998: 'harbor',
#  999: 'strength',
#  1000: 'leak',
#  ...}

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 164 : chapter
# 5611 : 1
# 11718 : loomings
# 390 : call
# 32 : me
# 640 : ishmael
# 46 : some
# 259 : years
# 778 : ago
# 111 : never
# 243 : mind
# 123 : how
# 93 : long
# 1138 : precisely
# 327 : having
# 86 : little
# 38 : or
# 44 : no
# 1137 : money
# 6 : in
# 39 : my
# 2182 : purse
# 3 : and
# 181 : nothing
# 421 : particular
# 5 : to

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('chapter', 1951),
#              ('1', 28),
#              ('loomings', 3),
#              ('call', 680),
#              ('me', 10015),
#              ('ishmael', 396),
#              ('some', 7287),
#              ('years', 1178),
#              ('ago', 321),
#              ('never', 3182),
#              ('mind', 1233),
#              ('how', 2820),
#              ('long', 3679),
#              ('precisely', 222),
#              ('having', 847),
#              ('little', 4124),
#              ('or', 8389),
#              ('no', 7402),
#              ('money', 227),
#              ('in', 48640),
#              ('my', 8237),
#              ('purse', 126),
#              ('and', 75709),
#              ('nothing', 1714),
#              ('particular', 649),
#              ('to', 56826),
#              ('interest', 390),
#              ('on', 12792),
#              ('shore', 416),
#              ('i', 31434),
#              ('thought', 2808),
#              ('would', 5928),
#              ('sail', 1326),
#              ('about', 4550),
#              ('a', 59819),
#              ('see', 3120),
#              ('the', 158076),
#              ('watery', 390),
#              ('part', 1664),
#              ('of', 79459),
#              ('world', 2366),
#              ('it', 28054),
#              ('is', 17498),
#              ('way', 3250),
#              ('have', 9152),
#              ('driving', 104),
#              ('off', 2678),
#              ('spleen', 26),
#              ('regulating', 26),
#              ('circulation', 26),
#              ('whenever', 260),
#              ('find', 728),
#              ('myself', 1196),
#              ('growing', 78),
#              ('grim', 182),
#              ('mouth', 520),
#              ('damp', 130),
#              ('drizzly', 26),
#              ('november', 52),
#              ('soul', 1300),
#              ('involuntarily', 130),
#              ('pausing', 156),
#              ('before', 3484),
#              ('coffin', 286),
#              ('warehouses', 52),
#              ('bringing', 182),
#              ('up', 6032),
#              ('rear', 286),
#              ('every', 2730),
#              ('funeral', 52),
#              ('meet', 234),
#              ('especially', 780),
#              ('hypos', 26),
#              ('get', 988),
#              ('such', 5070),
#              ('an', 6526),
#              ('upper', 130),
#              ('hand', 2470),
#              ('that', 37180),
#              ('requires', 104),
#              ('strong', 494),
#              ('moral', 52),
#              ('principle', 78),
#              ('prevent', 52),
#              ('from', 12818),
#              ('deliberately', 130),
#              ('stepping', 130),
#              ('into', 5694),
#              ('street', 260),
#              ('methodically', 52),
#              ('knocking', 130),
#              ('people', 780),
#              ("'s", 17706),
#              ('hats', 52),
#              ('then', 7410),
#              ('account', 546),
#              ('high', 1222),
#              ('time', 4264),
#              ('sea', 4862),
#              ('as', 20072),
#              ('soon', 1482),
#              ('can', 2834),
#              ('this', 15704),
#              ('substitute', 52),
#              ('for', 19474),
#              ('pistol', 156),
#              ('ball', 156),
#              ('with', 20696),
#              ('philosophical', 26),
#              ('flourish', 78),
#              ('cato', 26),
#              ('throws', 52),
#              ('himself', 3250),
#              ('upon', 7098),
#              ('his', 32370),
#              ('sword', 312),
#              ('quietly', 390),
#              ('take', 1690),
#              ('ship', 6356),
#              ('there', 11232),
#              ('surprising', 104),
#              ('if', 5512),
#              ('they', 7956),
#              ('but', 21658),
#              ('knew', 806),
#              ('almost', 2210),
#              ('all', 19500),
#              ('men', 3250),
#              ('their', 6682),
#              ('degree', 390),
#              ('other', 4862),
#              ('cherish', 156),
#              ('very', 4056),
#              ('nearly', 442),
#              ('same', 2444),
#              ('feelings', 104),
#              ('towards', 1456),
#              ('ocean', 910),
#              ('now', 7722),
#              ('your', 3198),
#              ('insular', 78),
#              ('city', 208),
#              ('manhattoes', 26),
#              ('belted', 52),
#              ('round', 2600),
#              ('by', 12818),
#              ('wharves', 104),
#              ('indian', 728),
#              ('isles', 130),
#              ('coral', 104),
#              ('reefs', 26),
#              ('commerce', 104),
#              ('surrounds', 26),
#              ('her', 4030),
#              ('surf', 26),
#              ('right', 1664),
#              ('left', 962),
#              ('streets', 338),
#              ('you', 9958),
#              ('waterward', 52),
#              ('its', 3276),
#              ('extreme', 182),
#              ('downtown', 26),
#              ('battery', 78),
#              ('where', 2418),
#              ('noble', 598),
#              ('mole', 52),
#              ('washed', 78),
#              ('waves', 598),
#              ('cooled', 26),
#              ('breezes', 78),
#              ('which', 7072),
#              ('few', 988),
#              ('hours', 468),
#              ('previous', 364),
#              ('were', 8606),
#              ('out', 6578),
#              ('sight', 910),
#              ('land', 1118),
#              ('look', 2158),
#              ('at', 16588),
#              ('crowds', 78),
#              ('water', 1768),
#              ('gazers', 26),
#              ('circumambulate', 26),
#              ('dreamy', 52),
#              ('sabbath', 52),
#              ('afternoon', 104),
#              ('go', 2314),
#              ('corlears', 26),
#              ('hook', 78),
#              ('coenties', 26),
#              ('slip', 78),
#              ('thence', 156),
#              ('whitehall', 26),
#              ('northward', 52),
#              ('what', 8190),
#              ('do', 5356),
#              ('see?--posted', 26),
#              ('like', 7306),
#              ('silent', 494),
#              ('sentinels', 26),
#              ('around', 416),
#              ('town', 650),
#              ('stand', 1144),
#              ('thousands', 130),
#              ('mortal', 468),
#              ('fixed', 572),
#              ('reveries', 78),
#              ('leaning', 338),
#              ('against', 1846),
#              ('spiles', 26),
#              ('seated', 416),
#              ('pier', 26),
#              ('heads', 832),
#              ('looking', 988),
#              ('over', 4810),
#              ('bulwarks', 468),
#              ('ships', 1248),
#              ('china', 104),
#              ('aloft', 364),
#              ('rigging', 286),
#              ('striving', 52),
#              ('still', 3666),
#              ('better', 910),
#              ('seaward', 52),
#              ('peep', 130),
#              ('these', 4498),
#              ('are', 5954),
#              ('landsmen', 182),
#              ('week', 52),
#              ('days', 1352),
#              ('pent', 26),
#              ('lath', 26),
#              ('plaster', 78),
#              ('tied', 78),
#              ('counters', 26),
#              ('nailed', 78),
#              ('benches', 52),
#              ('clinched', 26),
#              ('desks', 26),
#              ('green', 702),
#              ('fields', 104),
#              ('gone', 624),
#              ('here', 3484),
#              ('come', 2236),
#              ('more', 6552),
#              ('pacing', 130),
#              ('straight', 546),
#              ('seemingly', 78),
#              ('bound', 468),
#              ('dive', 130),
#              ('strange', 1222),
#              ('will', 4212),
#              ('content', 286),
#              ('them', 5538),
#              ('extremest', 26),
#              ('limit', 52),
#              ('loitering', 26),
#              ('under', 1222),
#              ('shady', 26),
#              ('lee', 260),
#              ('yonder', 286),
#              ('not', 15600),
#              ('suffice', 52),
#              ('must', 3068),
#              ('just', 1534),
#              ('nigh', 494),
#              ('possibly', 312),
#              ('without', 2106),
#              ('falling', 52),
#              ('miles', 416),
#              ('leagues', 130),
#              ('inlanders', 26),
#              ('lanes', 26),
#              ('alleys', 26),
#              ('avenues', 78),
#              ('north', 208),
#              ('east', 130),
#              ('south', 312),
#              ('west', 130),
#              ('yet', 4524),
#              ('unite', 130),
#              ('tell', 1898),
#              ('does', 1378),
#              ('magnetic', 104),
#              ('virtue', 130),
#              ('needles', 104),
#              ('compasses', 52),
#              ('those', 4238),
#              ('attract', 26),
#              ('thither', 104),
#              ('once', 1534),
#              ('say', 3250),
#              ('country', 312),
#              ('lakes', 26),
#              ('any', 4290),
#              ('path', 104),
#              ('please', 156),
#              ('ten', 520),
#              ('one', 9647),
#              ('carries', 130),
#              ('down', 4810),
#              ('dale', 26),
#              ('leaves', 234),
#              ('pool', 26),
#              ('stream', 130),
#              ('magic', 104),
#              ('let', 1560),
#              ('most', 3458),
#              ('absent', 208),
#              ('minded', 130),
#              ('be', 13234),
#              ('plunged', 104),
#              ('deepest', 104),
#              ('man', 6344),
#              ('legs', 442),
#              ('set', 988),
#              ('feet', 1092),
#              ('going', 1300),
#              ('he', 25688),
#              ('infallibly', 156),
#              ('lead', 260),
#              ('region', 52),
#              ('should', 1976),
#              ('ever', 2652),
#              ('athirst', 78),
#              ('great', 3406),
#              ('american', 572),
#              ('desert', 78),
#              ('try', 390),
#              ('experiment', 52),
#              ('caravan', 26),
#              ('happen', 130),
#              ('supplied', 104),
#              ('metaphysical', 52),
#              ('professor', 26),
#              ('yes', 884),
#              ('knows', 390),
#              ('meditation', 78),
#              ('wedded', 78),
#              ('artist', 78),
#              ('desires', 78),
#              ('paint', 78),
#              ('dreamiest', 26),
#              ('shadiest', 26),
#              ('quietest', 26),
#              ('enchanting', 26),
#              ('bit', 338),
#              ('romantic', 130),
#              ('landscape', 52),
#              ('valley', 52),
#              ('saco', 26),
#              ('chief', 702),
#              ('element', 104),
#              ('employs', 52),
#              ('trees', 208),
#              ('each', 1586),
#              ('hollow', 312),
#              ('trunk', 104),
#              ('hermit', 52),
#              ('crucifix', 26),
#              ('within', 936),
#              ('sleeps', 104),
#              ('meadow', 52),
#              ('sleep', 832),
#              ('cattle', 52),
#              ('cottage', 52),
#              ('goes', 676),
#              ('sleepy', 78),
#              ('smoke', 312),
#              ('deep', 780),
#              ('distant', 390),
#              ('woodlands', 52),
#              ('winds', 364),
#              ('mazy', 26),
#              ('reaching', 234),
#              ('overlapping', 26),
#              ('spurs', 26),
#              ('mountains', 208),
#              ('bathed', 26),
#              ('hill', 130),
#              ('side', 1742),
#              ('blue', 442),
#              ('though', 4992),
#              ('picture', 182),
#              ('lies', 156),
#              ('thus', 1248),
#              ('tranced', 52),
#              ('pine', 156),
#              ('tree', 234),
#              ('shakes', 26),
#              ('sighs', 52),
#              ('shepherd', 52),
#              ('head', 2964),
#              ('vain', 416),
#              ('unless', 390),
#              ('eye', 1118),
#              ('him', 13754),
#              ('visit', 208),
#              ('prairies', 104),
#              ('june', 52),
#              ('when', 7046),
#              ('scores', 104),
#              ('wade', 26),
#              ('knee', 130),
#              ('among', 2236),
#              ('tiger', 130),
#              ('lilies', 26),
#              ('charm', 130),
#              ('wanting?--water', 26),
#              ('drop', 208),
#              ('niagara', 26),
#              ('cataract', 52),
#              ('sand', 130),
#              ('travel', 130),
#              ('thousand', 520),
#              ('why', 1638),
#              ('did', 3822),
#              ('poor', 884),
#              ('poet', 52),
#              ('tennessee', 26),
#              ('suddenly', 468),
#              ('receiving', 234),
#              ('two', 2964),
#              ('handfuls', 52),
#              ('silver', 234),
#              ('deliberate', 104),
#              ('whether', 1066),
#              ('buy', 78),
#              ('coat', 468),
#              ('sadly', 182),
#              ('needed', 104),
#              ('invest', 78),
#              ('pedestrian', 52),
#              ('trip', 104),
#              ('rockaway', 26),
#              ('beach', 312),
#              ('robust', 52),
#              ('healthy', 104),
#              ('boy', 676),
#              ('crazy', 182),
#              ('first', 2860),
#              ('voyage', 1707),
#              ('passenger', 156),
#              ('yourself', 390),
#              ('feel', 702),
#              ('mystical', 130),
#              ('vibration', 104),
#              ('told', 780),
#              ('old', 5382),
#              ('persians', 26),
#              ('hold', 910),
#              ('holy', 468),
#              ('greeks', 26),
#              ('give', 1144),
#              ('separate', 260),
#              ('deity', 78),
#              ('own', 2782),
#              ('brother', 130),
#              ('jove', 78),
#              ('surely', 78),
#              ('meaning', 234),
#              ('deeper', 208),
#              ('story', 650),
#              ('narcissus', 26),
#              ('who', 5486),
#              ('because', 1118),
#              ('could', 3276),
#              ('grasp', 26),
#              ('tormenting', 26),
#              ('mild', 286),
#              ('image', 234),
#              ('saw', 1040),
#              ('fountain', 104),
#              ('was', 22074),
#              ('drowned', 52),
#              ('we', 5902),
#              ('ourselves', 286),
#              ('rivers', 78),
#              ('oceans', 260),
#              ('ungraspable', 26),
#              ('phantom', 260),
#              ('life', 1742),
#              ('key', 260),
#              ('am', 1222),
#              ('habit', 26),
#              ('begin', 104),
#              ('grow', 286),
#              ('hazy', 26),
#              ('eyes', 1612),
#              ('conscious', 130),
#              ('lungs', 260),
#              ('mean', 624),
#              ('inferred', 78),
#              ('needs', 260),
#              ('rag', 52),
#              ('something', 1820),
#              ('besides', 702),
#              ('passengers', 130),
#              ('sick', 130),
#              ('quarrelsome', 26),
#              ("don't", 130),
#              ('nights', 182),
#              ('enjoy', 104),
#              ('themselves', 624),
#              ('much', 3016),
#              ('general', 676),
#              ('thing;--no', 26),
#              ('nor', 2028),
#              ('salt', 208),
#              ('commodore', 208),
#              ('captain', 5616),
#              ('cook', 130),
#              ('abandon', 52),
#              ('glory', 312),
#              ('distinction', 78),
#              ('offices', 26),
#              ('abominate', 26),
#              ('honourable', 130),
#              ('respectable', 78),
#              ('toils', 26),
#              ('trials', 26),
#              ('tribulations', 52),
#              ('kind', 364),
#              ('whatsoever', 52),
#              ('quite', 624),
#              ('care', 156),
#              ('taking', 598),
#              ('barques', 26),
#              ('brigs', 52),
#              ('schooners', 26),
#              ('cook,--though', 26),
#              ('confess', 130),
#              ('considerable', 260),
#              ('being', 2730),
#              ('sort', 2548),
#              ('officer', 312),
#              ('board', 1196),
#              ('somehow', 728),
#              ('fancied', 104),
#              ('broiling', 26),
#              ('fowls;--though', 26),
#              ('broiled', 78),
#              ('judiciously', 52),
#              ('buttered', 26),
#              ('judgmatically', 26),
#              ('salted', 78),
#              ('peppered', 26),
#              ('speak', 494),
#              ('respectfully', 52),
#              ('reverentially', 26),
#              ('fowl', 104),
#              ('than', 3874),
#              ('idolatrous', 26),
#              ('dotings', 26),
#              ('egyptians', 104),
#              ('ibis', 26),
#              ('roasted', 26),
#              ('river', 52),
#              ('horse', 208),
#              ('mummies', 26),
#              ('creatures', 260),
#              ('huge', 260),
#              ('bake', 26),
#              ('houses', 130),
#              ('pyramids', 52),
#              ('simple', 182),
#              ('sailor', 1586),
#              ('mast', 1560),
#              ('plumb', 26),
#              ('forecastle', 494),
#              ('royal', 260),
#              ('true', 1144),
#              ('rather', 988),
#              ('order', 806),
#              ('make', 1378),
#              ('jump', 208),
#              ('spar', 78),
#              ('grasshopper', 52),
#              ('may', 2678),
#              ('thing', 1976),
#              ('unpleasant', 26),
#              ('enough', 1040),
#              ('touches', 52),
#              ('sense', 208),
#              ('honour', 338),
#              ('particularly', 182),
#              ('established', 52),
#              ('family', 182),
#              ('van', 78),
#              ('rensselaers', 26),
#              ('randolphs', 26),
#              ('hardicanutes', 26),
#              ('putting', 260),
#              ('tar', 130),
#              ('pot', 104),
#              ('been', 4966),
#              ('lording', 26),
#              ('schoolmaster', 52),
#              ('making', 520),
#              ('tallest', 26),
#              ('boys', 650),
#              ('awe', 208),
#              ('transition', 104),
#              ('keen', 156),
#              ('assure', 130),
#              ('decoction', 26),
#              ('seneca', 26),
#              ('stoics', 26),
#              ('enable', 78),
#              ('grin', 130),
#              ('bear', 598),
#              ('even', 2496),
#              ('wears', 52),
#              ('hunks', 78),
#              ('orders', 260),
#              ('broom', 78),
#              ('sweep', 182),
#              ('decks', 312),
#              ('indignity', 52),
#              ('amount', 104),
#              ('weighed', 52),
#              ('scales', 78),
#              ('new', 1508),
#              ('testament', 26),
#              ('think', 1742),
#              ('archangel', 52),
#              ('gabriel', 26),
#              ('thinks', 416),
#              ('anything', 650),
#              ('less', 598),
#              ('promptly', 26),
#              ('obey', 156),
#              ('instance', 312),
#              ('ai', 494),
#              ("n't", 3640),
#              ('slave', 182),
#              ('well', 3172),
#              ('however', 1300),
#              ('captains', 416),
#              ('thump', 130),
#              ('punch', 26),
#              ('satisfaction', 52),
#              ('knowing', 234),
#              ('everybody', 156),
#              ('else', 468),
#              ('served', 156),
#              ('either', 572),
#              ('physical', 78),
#              ('point', 702),
#              ('view', 416),
#              ('so', 11700),
#              ('universal', 78),
#              ('passed', 416),
#              ('hands', 1274),
#              ('rub', 26),
#              ('shoulder', 104),
#              ('blades', 52),
#              ('again', 2730),
#              ('always', 1014),
#              ('paying', 78),
#              ('trouble', 104),
#              ('whereas', 234),
#              ('pay', 234),
#              ('single', 390),
#              ('penny', 78),
#              ('heard', 1352),
#              ('contrary', 156),
#              ('difference', 208),
#              ('between', 1430),
#              ('paid', 130),
#              ('act', 208),
#              ('perhaps', 1404),
#              ('uncomfortable', 78),
#              ('infliction', 26),
#              ('orchard', 26),
#              ('thieves', 52),
#              ('entailed', 26),
#              ('us', 3224),
#              ('paid,--what', 26),
#              ('compare', 78),
#              ('urbane', 26),
#              ('activity', 52),
#              ('receives', 26),
#              ('really', 338),
#              ('marvellous', 286),
#              ('considering', 494),
#              ('earnestly', 130),
#              ('believe', 182),
#              ('root', 52),
#              ('earthly', 182),
#              ('ills', 26),
#              ('monied', 26),
#              ('enter', 182),
#              ('heaven', 572),
#              ('ah', 364),
#              ('cheerfully', 52),
#              ('consign', 26),
#              ('perdition', 52),
#              ('finally', 416),
#              ('wholesome', 26),
#              ('exercise', 26),
#              ('pure', 78),
#              ('air', 1248),
#              ('fore', 312),
#              ('castle', 104),
#              ('deck', 2080),
#              ('far', 1742),
#              ('prevalent', 26),
#              ('astern', 182),
#              ('violate', 26),
#              ('pythagorean', 26),
#              ('maxim', 52),
#              ('quarter', 624),
#              ('gets', 26),
#              ('atmosphere', 26),
#              ('second', 624),
#              ('sailors', 884),
#              ('breathes', 52),
#              ('commonalty', 26),
#              ('leaders', 52),
#              ('many', 2288),
#              ('things', 1924),
#              ('suspect', 78),
#              ('wherefore', 104),
#              ('after', 3302),
#              ('repeatedly', 26),
#              ('smelt', 52),
#              ('merchant', 364),
#              ('whaling', 2072),
#              ('invisible', 182),
#              ('police', 26),
#              ('fates', 78),
#              ('has', 3406),
#              ('constant', 78),
#              ('surveillance', 26),
#              ('secretly', 26),
#              ('dogs', 130),
#              ('influences', 182),
#              ('unaccountable', 312),
#              ('answer', 442),
#              ('doubtless', 260),
#              ('formed', 364),
#              ('grand', 858),
#              ('programme', 26),
#              ('providence', 26),
#              ('drawn', 364),
#              ('came', 1638),
#              ('brief', 156),
#              ('interlude', 26),
#              ('solo', 26),
#              ('extensive', 26),
#              ('performances', 78),
#              ('bill', 182),
#              ('run', 624),
#              ('contested', 26),
#              ('election', 26),
#              ('presidency', 26),
#              ('united', 104),
#              ('states', 78),
#              ('bloody', 156),
#              ('battle', 286),
#              ('affghanistan', 26),
#              ('exactly', 234),
#              ('stage', 130),
#              ('managers', 26),
#              ('put', 988),
#              ('shabby', 78),
#              ('others', 390),
#              ('magnificent', 52),
#              ('parts', 416),
#              ('tragedies', 52),
#              ('short', 676),
#              ('easy', 650),
#              ('genteel', 26),
#              ('comedies', 26),
#              ('jolly', 234),
#              ('farces', 26),
#              ('recall', 104),
#              ('circumstances', 364),
#              ('springs', 52),
#              ('motives', 78),
#              ('cunningly', 26),
#              ('presented', 260),
#              ('various', 572),
#              ('disguises', 26),
#              ('induced', 52),
#              ('performing', 52),
#              ('cajoling', 26),
#              ('delusion', 26),
#              ('choice', 78),
#              ('resulting', 52),
#              ('unbiased', 26),
#              ('freewill', 26),
#              ('discriminating', 26),
#              ('judgment', 182),
#              ('overwhelming', 26),
#              ('idea', 520),
#              ('whale', 10226),
#              ('portentous', 130),
#              ('mysterious', 130),
#              ('monster', 494),
#              ('roused', 26),
#              ('curiosity', 130),
#              ('wild', 1326),
#              ('seas', 1326),
#              ('rolled', 598),
#              ('island', 728),
#              ('bulk', 78),
#              ('undeliverable', 26),
#              ('nameless', 312),
#              ('perils', 468),
#              ('attending', 52),
#              ('marvels', 130),
#              ('patagonian', 52),
#              ('sights', 156),
#              ('sounds', 156),
#              ('helped', 156),
#              ('sway', 26),
#              ('wish', 156),
#              ('inducements', 52),
#              ('tormented', 182),
#              ('everlasting', 156),
#              ('itch', 26),
#              ('remote', 156),
#              ('love', 286),
#              ('forbidden', 26),
#              ('barbarous', 52),
#              ('coasts', 78),
#              ('ignoring', 26),
#              ('good', 2964),
#              ('quick', 468),
#              ('perceive', 52),
#              ('horror', 208),
#              ('social', 260),
#              ('since', 832),
#              ('friendly', 78),
#              ('terms', 182),
#              ('inmates', 52),
#              ('place', 1534),
#              ('lodges', 26),
#              ('reason', 676),
#              ('welcome', 52),
#              ('flood', 130),
#              ('gates', 26),
#              ('wonder', 494),
#              ('swung', 260),
#              ('open', 1040),
#              ('conceits', 78),
#              ('swayed', 52),
#              ('purpose', 572),
#              ('floated', 156),
#              ('inmost', 26),
#              ('endless', 208),
#              ('processions', 78),
#              ('mid', 156),
#              ('hooded', 78),
#              ('snow', 546),
#              ('\n\n\n\n', 1378),
#              ('2', 26),
#              ('carpet', 104),
#              ('bag', 286),
#              ('stuffed', 52),
#              ('shirt', 182),
#              ('tucked', 78),
#              ('arm', 858),
#              ('started', 286),
#              ('cape', 754),
#              ('horn', 650),
#              ('pacific', 468),
#              ('quitting', 104),
#              ('manhatto', 26),
#              ('duly', 52),
#              ('arrived', 234),
#              ('bedford', 416),
#              ('saturday', 78),
#              ('night', 2184),
#              ('december', 52),
#              ('disappointed', 52),
#              ('learning', 104),
#              ('packet', 78),
#              ('nantucket', 1586),
#              ('had', 10062),
#              ('already', 338),
#              ('sailed', 676),
#              ('offer', 104),
#              ('till', 1352),
#              ('following', 390),
#              ('monday', 52),
#              ('young', 1196),
#              ('candidates', 26),
#              ('pains', 104),
#              ('penalties', 26),
#              ('stop', 494),
#              ('embark', 130),
#              ('related', 78),
#              ('doing', 182),
#              ('made', 2314),
#              ('craft', 832),
#              ('fine', 754),
#              ('boisterous', 78),
#              ('everything', 234),
#              ('connected', 156),
#              ('famous', 624),
#              ('amazingly', 52),
#              ('pleased', 130),
#              ('late', 364),
#              ('gradually', 78),
#              ('monopolising', 26),
#              ('business', 936),
#              ('matter', 1196),
#              ('behind', 494),
#              ('original', 286),
#              ('tyre', 26),
#              ('carthage;--the', 26),
#              ('dead', 884),
#              ('stranded', 130),
#              ('aboriginal', 78),
#              ('whalemen', 988),
#              ('red', 416),
#              ('sally', 26),
#              ('canoes', 104),
#              ('chase', 546),
#              ('leviathan', 468),
#              ('too', 2028),
#              ('adventurous', 104),
#              ('sloop', 78),
#              ('forth', 572),
#              ('partly', 130),
#              ('laden', 26),
#              ('imported', 26),
#              ('cobblestones', 26),
#              ('throw', 260),
#              ('whales', 2652),
#              ('discover', 52),
#              ('risk', 78),
#              ('harpoon', 780),
#              ('bowsprit', 104),
#              ('day', 1976),
#              ('another', 1222),
#              ('ere', 832),
#              ('destined', 52),
#              ('port', 520),
#              ('became', 338),
#              ('concernment', 52),
#              ('eat', 52),
#              ('meanwhile', 468),
#              ('dubious', 26),
#              ('nay', 442),
#              ('dark', 728),
#              ('dismal', 182),
#              ('bitingly', 26),
#              ('cold', 728),
#              ('cheerless', 78),
#              ('anxious', 182),
#              ('grapnels', 26),
#              ('sounded', 104),
#              ('pocket', 130),
#              ('only', 4264),
#              ('brought', 364),
#              ('pieces', 78),
#              ('silver,--so', 26),
#              ('wherever', 104),
#              ('said', 4550),
#              ('stood', 1196),
#              ('middle', 234),
#              ('dreary', 156),
#              ('shouldering', 26),
#              ('comparing', 26),
#              ('gloom', 104),
#              ('darkness', 312),
#              ('wisdom', 52),
#              ('conclude', 104),
#              ('lodge', 78),
#              ('dear', 104),
#              ('sure', 754),
#              ('inquire', 52),
#              ('price', 26),
#              ('halting', 52),
#              ('steps', 104),
#              ('paced', 156),
#              ('sign', 546),
#              ('crossed', 182),
#              ('harpoons"--but', 26),
#              ('looked', 1222),
#              ('expensive', 52),
#              ('further', 598),
#              ('bright', 260),
#              ('windows', 78),
#              ('fish', 1586),
#              ('inn', 364),
#              ('fervent', 26),
#              ('rays', 26),
#              ('seemed', 3718),
#              ('melted', 78),
#              ('packed', 78),
#              ('ice', 364),
#              ('house', 728),
#              ('everywhere', 104),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)

# %% [markdown]
# ### Convert to Numpy Matrix

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[  164,  5611, 11718, ...,   181,   421,     5],
#        [ 5611, 11718,   390, ...,   421,     5,   641],
#        [11718,   390,    32, ...,     5,   641,    32],
#        ...,
#        [   25,     4,  1490, ...,     2, 11717,  1286],
#        [    4,  1490,   289, ..., 11717,  1286,     6],
#        [ 1490,   289,     2, ...,  1286,     6,    34]])

# %% [markdown]
# # Creating an LSTM based model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding

# %%
def create_model(vocabulary_size, seq_len):
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    model.add(LSTM(150, return_sequences=True))
    model.add(LSTM(150))
    model.add(Dense(150, activation='relu'))

    model.add(Dense(vocabulary_size, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    model.summary()

    return model

# %% [markdown]
# ### Train / Test Split

# %%
from keras.utils import to_categorical

# %%
sequences
# Out:
# array([[  164,  5611, 11718, ...,   181,   421,     5],
#        [ 5611, 11718,   390, ...,   421,     5,   641],
#        [11718,   390,    32, ...,     5,   641,    32],
#        ...,
#        [   25,     4,  1490, ...,     2, 11717,  1286],
#        [    4,  1490,   289, ..., 11717,  1286,     6],
#        [ 1490,   289,     2, ...,  1286,     6,    34]])

# %%
# First 49 words
sequences[:,:-1]
# Out:
# array([[  164,  5611, 11718, ...,     3,   181,   421],
#        [ 5611, 11718,   390, ...,   181,   421,     5],
#        [11718,   390,    32, ...,   421,     5,   641],
#        ...,
#        [   25,     4,  1490, ..., 11716,     2, 11717],
#        [    4,  1490,   289, ...,     2, 11717,  1286],
#        [ 1490,   289,     2, ..., 11717,  1286,     6]])

# %%
# last Word
sequences[:,-1]
# Out:
# array([   5,  641,   32, ..., 1286,    6,   34])

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
print(type(y),len(y),y.shape,y.ndim,y)
# Out:
# <class 'numpy.ndarray'> 99974 (99974,) 1 [   5  641   32 ... 1286    6   34]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]

# %%
seq_len
# Out:
# 25

# %% [markdown]
# ### Training the Model

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 25)            292975
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 25, 150)           105600
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 150)               180600
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               22650
# _________________________________________________________________
# dense_3 (Dense)              (None, 11719)             1769569
# =================================================================
# Total params: 2,371,394
# Trainable params: 2,371,394
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ---
#
# ----

# %%
from pickle import dump,load

# %%
# fit model
model.fit(X, y, batch_size=128, epochs=300,verbose=1)
# Out:
# Epoch 1/300
# 782/782 [==============================] - 16s 17ms/step - loss: 7.2861 - accuracy: 0.0566
# Epoch 2/300
# 782/782 [==============================] - 13s 17ms/step - loss: 6.6222 - accuracy: 0.0713
# Epoch 3/300
# 782/782 [==============================] - 13s 17ms/step - loss: 6.4388 - accuracy: 0.0797
# Epoch 4/300
# 782/782 [==============================] - 13s 17ms/step - loss: 6.2337 - accuracy: 0.0910
# Epoch 5/300
# 782/782 [==============================] - 13s 17ms/step - loss: 6.0978 - accuracy: 0.0999
# Epoch 6/300
# 782/782 [==============================] - 13s 17ms/step - loss: 5.9556 - accuracy: 0.1041
# Epoch 7/300
# 782/782 [==============================] - 13s 17ms/step - loss: 5.8489 - accuracy: 0.1081
# Epoch 8/300
# 782/782 [==============================] - 13s 17ms/step - loss: 5.7262 - accuracy: 0.1105
# Epoch 9/300
# 782/782 [==============================] - 13s 16ms/step - loss: 5.5972 - accuracy: 0.1154
# Epoch 10/300
# 782/782 [==============================] - 13s 16ms/step - loss: 5.4773 - accuracy: 0.1157
# Epoch 11/300
# 782/782 [==============================] - 13s 16ms/step - loss: 5.3518 - accuracy: 0.1205
# Epoch 12/300
# 782/782 [==============================] - 13s 17ms/step - loss: 5.2497 - accuracy: 0.1220
# Epoch 13/300
# 782/782 [==============================] - 13s 16ms/step - loss: 5.1542 - accuracy: 0.1233
# Epoch 14/300
# 782/782 [==============================] - 13s 16ms/step - loss: 5.0416 - accuracy: 0.1281
# Epoch 15/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.9497 - accuracy: 0.1310
# Epoch 16/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.8568 - accuracy: 0.1326
# Epoch 17/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.8845 - accuracy: 0.1324
# Epoch 18/300
# 782/782 [==============================] - 13s 17ms/step - loss: 4.7091 - accuracy: 0.1422
# Epoch 19/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.6391 - accuracy: 0.1453
# Epoch 20/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.5524 - accuracy: 0.1497
# Epoch 21/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.5175 - accuracy: 0.1560
# Epoch 22/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.4247 - accuracy: 0.1624
# Epoch 23/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.3402 - accuracy: 0.1716
# Epoch 24/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.3214 - accuracy: 0.1734
# Epoch 25/300
# 782/782 [==============================] - 13s 17ms/step - loss: 4.2674 - accuracy: 0.1793
# Epoch 26/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.2936 - accuracy: 0.1787
# Epoch 27/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.2309 - accuracy: 0.1813
# Epoch 28/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.1857 - accuracy: 0.1865
# Epoch 29/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.1363 - accuracy: 0.1937
# Epoch 30/300
# 782/782 [==============================] - 13s 16ms/step - loss: 4.0582 - accuracy: 0.2019
# Epoch 31/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.9851 - accuracy: 0.2101
# Epoch 32/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.9628 - accuracy: 0.2136
# Epoch 33/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.9135 - accuracy: 0.2191
# Epoch 34/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.8666 - accuracy: 0.2251
# Epoch 35/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.8160 - accuracy: 0.2318
# Epoch 36/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.7731 - accuracy: 0.2379
# Epoch 37/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.7363 - accuracy: 0.2417
# Epoch 38/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.6750 - accuracy: 0.2543
# Epoch 39/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.6435 - accuracy: 0.2543
# Epoch 40/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.6139 - accuracy: 0.2604
# Epoch 41/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.5950 - accuracy: 0.2648
# Epoch 42/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.5890 - accuracy: 0.2648
# Epoch 43/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.6061 - accuracy: 0.2641
# Epoch 44/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.7181 - accuracy: 0.2504
# Epoch 45/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.8388 - accuracy: 0.2327
# Epoch 46/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.6587 - accuracy: 0.2561
# Epoch 47/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.6161 - accuracy: 0.2626
# Epoch 48/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.5719 - accuracy: 0.2698
# Epoch 49/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.5079 - accuracy: 0.2785
# Epoch 50/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.7250 - accuracy: 0.2507
# Epoch 51/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.6832 - accuracy: 0.2507
# Epoch 52/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.5192 - accuracy: 0.2744
# Epoch 53/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.4778 - accuracy: 0.2809
# Epoch 54/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.4192 - accuracy: 0.2888
# Epoch 55/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.3774 - accuracy: 0.2941
# Epoch 56/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.3325 - accuracy: 0.3025
# Epoch 57/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.2721 - accuracy: 0.3115
# Epoch 58/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.2497 - accuracy: 0.3125
# Epoch 59/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.2299 - accuracy: 0.3140
# Epoch 60/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.1939 - accuracy: 0.3234
# Epoch 61/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.1656 - accuracy: 0.3259
# Epoch 62/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.1452 - accuracy: 0.3303
# Epoch 63/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.4528 - accuracy: 0.2804
# Epoch 64/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.1696 - accuracy: 0.3245
# Epoch 65/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.1034 - accuracy: 0.3390
# Epoch 66/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.0518 - accuracy: 0.3460
# Epoch 67/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.0225 - accuracy: 0.3501
# Epoch 68/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.9738 - accuracy: 0.3582
# Epoch 69/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.9439 - accuracy: 0.3650
# Epoch 70/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.9226 - accuracy: 0.3660
# Epoch 71/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.8792 - accuracy: 0.3720
# Epoch 72/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.8501 - accuracy: 0.3793
# Epoch 73/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.8187 - accuracy: 0.3827
# Epoch 74/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.7986 - accuracy: 0.3870
# Epoch 75/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.7636 - accuracy: 0.3928
# Epoch 76/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.7323 - accuracy: 0.3985
# Epoch 77/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.7039 - accuracy: 0.4027
# Epoch 78/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.6758 - accuracy: 0.4057
# Epoch 79/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6539 - accuracy: 0.4102
# Epoch 80/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6603 - accuracy: 0.4089
# Epoch 81/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.6177 - accuracy: 0.4174
# Epoch 82/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5966 - accuracy: 0.4224
# Epoch 83/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5640 - accuracy: 0.4262
# Epoch 84/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5993 - accuracy: 0.4220
# Epoch 85/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6621 - accuracy: 0.4130
# Epoch 86/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.3489 - accuracy: 0.3144
# Epoch 87/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.2289 - accuracy: 0.3192
# Epoch 88/300
# 782/782 [==============================] - 13s 17ms/step - loss: 3.1425 - accuracy: 0.3338
# Epoch 89/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.0830 - accuracy: 0.3410
# Epoch 90/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.1417 - accuracy: 0.3347
# Epoch 91/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.0987 - accuracy: 0.3354
# Epoch 92/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.7735 - accuracy: 0.3890
# Epoch 93/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6178 - accuracy: 0.4178
# Epoch 94/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5671 - accuracy: 0.4266
# Epoch 95/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5330 - accuracy: 0.4326
# Epoch 96/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5097 - accuracy: 0.4361
# Epoch 97/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5280 - accuracy: 0.4381
# Epoch 98/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.4729 - accuracy: 0.4464
# Epoch 99/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6465 - accuracy: 0.4221
# Epoch 100/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.9741 - accuracy: 0.3670
# Epoch 101/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.8507 - accuracy: 0.3824
# Epoch 102/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.6720 - accuracy: 0.4126
# Epoch 103/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.6088 - accuracy: 0.4212
# Epoch 104/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.5440 - accuracy: 0.4326
# Epoch 105/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.5073 - accuracy: 0.4395
# Epoch 106/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.4383 - accuracy: 0.4499
# Epoch 107/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.3564 - accuracy: 0.4656
# Epoch 108/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.3022 - accuracy: 0.4753
# Epoch 109/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.3455 - accuracy: 0.4686
# Epoch 110/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.3156 - accuracy: 0.4739
# Epoch 111/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.2679 - accuracy: 0.4796
# Epoch 112/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.2094 - accuracy: 0.4946
# Epoch 113/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.1955 - accuracy: 0.4968
# Epoch 114/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.1935 - accuracy: 0.4960
# Epoch 115/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.2000 - accuracy: 0.4965
# Epoch 116/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5110 - accuracy: 0.4344
# Epoch 117/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.2115 - accuracy: 0.4954
# Epoch 118/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.1343 - accuracy: 0.5093
# Epoch 119/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1087 - accuracy: 0.5125
# Epoch 120/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.0758 - accuracy: 0.5194
# Epoch 121/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0647 - accuracy: 0.5207
# Epoch 122/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0249 - accuracy: 0.5280
# Epoch 123/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.0260 - accuracy: 0.5293
# Epoch 124/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0087 - accuracy: 0.5332
# Epoch 125/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9816 - accuracy: 0.5393
# Epoch 126/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9560 - accuracy: 0.5414
# Epoch 127/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9349 - accuracy: 0.5451
# Epoch 128/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9458 - accuracy: 0.5453
# Epoch 129/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9628 - accuracy: 0.5438
# Epoch 130/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0148 - accuracy: 0.5338
# Epoch 131/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9643 - accuracy: 0.5436
# Epoch 132/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0076 - accuracy: 0.5375
# Epoch 133/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9218 - accuracy: 0.5506
# Epoch 134/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9116 - accuracy: 0.5533
# Epoch 135/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8541 - accuracy: 0.5633
# Epoch 136/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8385 - accuracy: 0.5663
# Epoch 137/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.8486 - accuracy: 0.5678
# Epoch 138/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0389 - accuracy: 0.5340
# Epoch 139/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9470 - accuracy: 0.5522
# Epoch 140/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8440 - accuracy: 0.5708
# Epoch 141/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.8275 - accuracy: 0.5733
# Epoch 142/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.8331 - accuracy: 0.5700
# Epoch 143/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8329 - accuracy: 0.5719
# Epoch 144/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9621 - accuracy: 0.5495
# Epoch 145/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.7799 - accuracy: 0.5792
# Epoch 146/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8676 - accuracy: 0.5701
# Epoch 147/300
# 782/782 [==============================] - 13s 16ms/step - loss: 3.1998 - accuracy: 0.3722
# Epoch 148/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.5097 - accuracy: 0.4546
# Epoch 149/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.7838 - accuracy: 0.4170
# Epoch 150/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.5802 - accuracy: 0.4382
# Epoch 151/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.3706 - accuracy: 0.4683
# Epoch 152/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.3883 - accuracy: 0.4676
# Epoch 153/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1453 - accuracy: 0.5121
# Epoch 154/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.0662 - accuracy: 0.5249
# Epoch 155/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.3534 - accuracy: 0.4754
# Epoch 156/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.2853 - accuracy: 0.4841
# Epoch 157/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.2226 - accuracy: 0.4940
# Epoch 158/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1446 - accuracy: 0.5083
# Epoch 159/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1248 - accuracy: 0.5109
# Epoch 160/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1462 - accuracy: 0.5082
# Epoch 161/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0954 - accuracy: 0.5188
# Epoch 162/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.0889 - accuracy: 0.5179
# Epoch 163/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0397 - accuracy: 0.5239
# Epoch 164/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.9315 - accuracy: 0.5449
# Epoch 165/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8650 - accuracy: 0.5600
# Epoch 166/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.8190 - accuracy: 0.5697
# Epoch 167/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.7828 - accuracy: 0.5767
# Epoch 168/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.7611 - accuracy: 0.5827
# Epoch 169/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.8068 - accuracy: 0.5696
# Epoch 170/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.7061 - accuracy: 0.5916
# Epoch 171/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.6998 - accuracy: 0.5939
# Epoch 172/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.7088 - accuracy: 0.5897
# Epoch 173/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6370 - accuracy: 0.6031
# Epoch 174/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6578 - accuracy: 0.6008
# Epoch 175/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6136 - accuracy: 0.6129
# Epoch 176/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.6164 - accuracy: 0.6085
# Epoch 177/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5861 - accuracy: 0.6183
# Epoch 178/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5787 - accuracy: 0.6191
# Epoch 179/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.5148 - accuracy: 0.6327
# Epoch 180/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.5303 - accuracy: 0.6270
# Epoch 181/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5770 - accuracy: 0.6190
# Epoch 182/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6490 - accuracy: 0.6116
# Epoch 183/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.5776 - accuracy: 0.6195
# Epoch 184/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5144 - accuracy: 0.6350
# Epoch 185/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6043 - accuracy: 0.6179
# Epoch 186/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.5762 - accuracy: 0.6204
# Epoch 187/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5489 - accuracy: 0.6291
# Epoch 188/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.4942 - accuracy: 0.6401
# Epoch 189/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.4683 - accuracy: 0.6452
# Epoch 190/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.4174 - accuracy: 0.6545
# Epoch 191/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.4363 - accuracy: 0.6452
# Epoch 192/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.3999 - accuracy: 0.6571
# Epoch 193/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.3883 - accuracy: 0.6615
# Epoch 194/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.3819 - accuracy: 0.6600
# Epoch 195/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.4023 - accuracy: 0.6587
# Epoch 196/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3967 - accuracy: 0.6619
# Epoch 197/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.4926 - accuracy: 0.6416
# Epoch 198/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3720 - accuracy: 0.6683
# Epoch 199/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3343 - accuracy: 0.6730
# Epoch 200/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.3377 - accuracy: 0.6738
# Epoch 201/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3404 - accuracy: 0.6744
# Epoch 202/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3530 - accuracy: 0.6708
# Epoch 203/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3501 - accuracy: 0.6689
# Epoch 204/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2620 - accuracy: 0.6909
# Epoch 205/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2669 - accuracy: 0.6897
# Epoch 206/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3210 - accuracy: 0.6774
# Epoch 207/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.2581 - accuracy: 0.6917
# Epoch 208/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2519 - accuracy: 0.6930
# Epoch 209/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2082 - accuracy: 0.7021
# Epoch 210/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2162 - accuracy: 0.6995
# Epoch 211/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.2056 - accuracy: 0.7003
# Epoch 212/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1591 - accuracy: 0.7105
# Epoch 213/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1374 - accuracy: 0.7170
# Epoch 214/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1328 - accuracy: 0.7167
# Epoch 215/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1000 - accuracy: 0.7259
# Epoch 216/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1843 - accuracy: 0.7017
# Epoch 217/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1007 - accuracy: 0.7247
# Epoch 218/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1043 - accuracy: 0.7223
# Epoch 219/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3080 - accuracy: 0.6841
# Epoch 220/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1520 - accuracy: 0.7146
# Epoch 221/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0813 - accuracy: 0.7315
# Epoch 222/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1272 - accuracy: 0.7219
# Epoch 223/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1179 - accuracy: 0.7222
# Epoch 224/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1062 - accuracy: 0.7249
# Epoch 225/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0248 - accuracy: 0.7445
# Epoch 226/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0697 - accuracy: 0.7320
# Epoch 227/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0575 - accuracy: 0.7362
# Epoch 228/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0363 - accuracy: 0.7412
# Epoch 229/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0479 - accuracy: 0.7398
# Epoch 230/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.7537 - accuracy: 0.4657
# Epoch 231/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.4963 - accuracy: 0.6396
# Epoch 232/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.5851 - accuracy: 0.6102
# Epoch 233/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1249 - accuracy: 0.7182
# Epoch 234/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0348 - accuracy: 0.7426
# Epoch 235/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0103 - accuracy: 0.7503
# Epoch 236/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0124 - accuracy: 0.7485
# Epoch 237/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9907 - accuracy: 0.7540
# Epoch 238/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0023 - accuracy: 0.7532
# Epoch 239/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0044 - accuracy: 0.7520
# Epoch 240/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0427 - accuracy: 0.7414
# Epoch 241/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0759 - accuracy: 0.7283
# Epoch 242/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9568 - accuracy: 0.7630
# Epoch 243/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.0413 - accuracy: 0.7439
# Epoch 244/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0323 - accuracy: 0.7443
# Epoch 245/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.2161 - accuracy: 0.7126
# Epoch 246/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9786 - accuracy: 0.7604
# Epoch 247/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9292 - accuracy: 0.7709
# Epoch 248/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9708 - accuracy: 0.7543
# Epoch 249/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9090 - accuracy: 0.7730
# Epoch 250/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9609 - accuracy: 0.7587
# Epoch 251/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.9390 - accuracy: 0.7643
# Epoch 252/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9745 - accuracy: 0.7594
# Epoch 253/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0552 - accuracy: 0.7453
# Epoch 254/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0410 - accuracy: 0.7449
# Epoch 255/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9062 - accuracy: 0.7758
# Epoch 256/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8882 - accuracy: 0.7803
# Epoch 257/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9376 - accuracy: 0.7664
# Epoch 258/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9725 - accuracy: 0.7637
# Epoch 259/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1866 - accuracy: 0.7193
# Epoch 260/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.2089 - accuracy: 0.7201
# Epoch 261/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2654 - accuracy: 0.7168
# Epoch 262/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9876 - accuracy: 0.7588
# Epoch 263/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8821 - accuracy: 0.7799
# Epoch 264/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.8226 - accuracy: 0.7916
# Epoch 265/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8336 - accuracy: 0.7878
# Epoch 266/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.8245 - accuracy: 0.7898
# Epoch 267/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8015 - accuracy: 0.7977
# Epoch 268/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8197 - accuracy: 0.7927
# Epoch 269/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8473 - accuracy: 0.7848
# Epoch 270/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.9106 - accuracy: 0.7707
# Epoch 271/300
# 782/782 [==============================] - 13s 17ms/step - loss: 0.8177 - accuracy: 0.7964
# Epoch 272/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.0931 - accuracy: 0.7457
# Epoch 273/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1205 - accuracy: 0.7373
# Epoch 274/300
# 782/782 [==============================] - 13s 16ms/step - loss: 0.8639 - accuracy: 0.7917
# Epoch 275/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.1259 - accuracy: 0.7363
# Epoch 276/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.8889 - accuracy: 0.5976
# Epoch 277/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.3791 - accuracy: 0.6866
# Epoch 278/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2555 - accuracy: 0.7105
# Epoch 279/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.1575 - accuracy: 0.5806
# Epoch 280/300
# 782/782 [==============================] - 13s 17ms/step - loss: 2.2771 - accuracy: 0.5603
# Epoch 281/300
# 782/782 [==============================] - 13s 16ms/step - loss: 2.0398 - accuracy: 0.5908
# Epoch 282/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.9225 - accuracy: 0.6031
# Epoch 283/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.7123 - accuracy: 0.6274
# Epoch 284/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.7039 - accuracy: 0.6256
# Epoch 285/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.7428 - accuracy: 0.6252
# Epoch 286/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.6146 - accuracy: 0.6460
# Epoch 287/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.5211 - accuracy: 0.6570
# Epoch 288/300
# 782/782 [==============================] - 13s 16ms/step - loss: 1.4588 - accuracy: 0.6652
# Epoch 289/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.4461 - accuracy: 0.6658
# Epoch 290/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3737 - accuracy: 0.6782
# Epoch 291/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3520 - accuracy: 0.6796
# Epoch 292/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.3456 - accuracy: 0.6781
# Epoch 293/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2856 - accuracy: 0.6922
# Epoch 294/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2680 - accuracy: 0.6945
# Epoch 295/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2330 - accuracy: 0.7045
# Epoch 296/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2877 - accuracy: 0.6819
# Epoch 297/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.2035 - accuracy: 0.7069
# Epoch 298/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1846 - accuracy: 0.7106
# Epoch 299/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1664 - accuracy: 0.7139
# Epoch 300/300
# 782/782 [==============================] - 13s 17ms/step - loss: 1.1968 - accuracy: 0.7043

# %%
# save the model to file
model_path="/content/drive/MyDrive/NLP2020/Text_Generation_keras/100ktokens_epochBIG.h5"
tokenizer_path="/content/drive/MyDrive/NLP2020/Text_Generation_keras/100ktokens_epochBIG"
model.save(model_path)
# save the tokenizer
dump(tokenizer, open(tokenizer_path, 'wb'))

# %% [markdown]
# # Generating New Text

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''

    # Final Output
    output_text = []

    # Intial Seed Sequence
    input_text = seed_text

    # Create num_gen_words
    for i in range(num_gen_words):

        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]

        # Pad sequences to our trained rate (50 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')

        # Predict Class Probabilities for each word
        pred_word_ind = model.predict_classes(pad_encoded, verbose=0)[0]

        # Grab word
        pred_word = tokenizer.index_word[pred_word_ind]

        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word

        output_text.append(pred_word)

    # Make it look like a sentence.
    return ' '.join(output_text)

# %% [markdown]
# ### Grab a random seed sequence

# %%
text_sequences[0]
# Out:
# ['chapter',
#  '1',
#  'loomings',
#  'call',
#  'me',
#  'ishmael',
#  'some',
#  'years',
#  'ago',
#  'never',
#  'mind',
#  'how',
#  'long',
#  'precisely',
#  'having',
#  'little',
#  'or',
#  'no',
#  'money',
#  'in',
#  'my',
#  'purse',
#  'and',
#  'nothing',
#  'particular',
#  'to']

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['a',
#  'clean',
#  'comely',
#  'looking',
#  'cannibal',
#  'what',
#  "'s",
#  'all',
#  'this',
#  'fuss',
#  'i',
#  'have',
#  'been',
#  'making',
#  'about',
#  'thought',
#  'i',
#  'to',
#  'myself',
#  'the',
#  'man',
#  "'s",
#  'a',
#  'human',
#  'being',
#  'just']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# "a clean comely looking cannibal what 's all this fuss i have been making about thought i to myself the man 's a human being just"

# %%
seed_text=seed_text[0:15]
seed_text='a clean comely looking cannibal what  all this fuss'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 'i had myself that one of a leg of the squares in the air and then to be seen a chair but it was a foot too narrow and the world scattered the hot yellow thou have run something and then he thought the villanous green years had endeavored to'

# %% [markdown]
# ### Exploring Generated Sequence

# %%
path="/content/drive/MyDrive/NLP2020/Text_Generation_keras/moby_book_four_chapters.txt"
full_text = read_file(path)

# %%
for i,word in enumerate(full_text.split()):
    if word == 'inkling':
        print(' '.join(full_text.split()[i-20:i+20]))
        print('\n')
# Out:
# were stains of some sort or other. At first I knew not what to make of this; but soon an inkling of the truth occurred to me. I remembered a story of a white man--a whaleman too--who, falling among the
